# %% [markdown]
# ## Starting Off
#
# Think of one lingering quetion you have about SQL and sedd it to our slack class channel.

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %%
#by 2 should have all data in the database and start doing SQL queries

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a serach of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
#individual api and client id cells
client_id = "iEJoh9Ld1tFc56m-OVijoA"
api_key = "OLhy45aVXLmJtClJ75M_1KgoH85lErHLSSSSLTyyeYKb0xTey06_AdUYT3xiEa6hhkHyK-5ttHePmB2wuxIWunAzl5ykGADyj4Ct3tIxkarF14dx8bznH4C4_mHpXXYx"

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'chinese'

#where do you want to perform this search
location = 'Manhattan'

# what is your other parameter you want to search against
attributes = 'hot_and_new'

# %%
#set parameters to a dictionary so they can be replaced easily
#need to replace spaces with plus signs so it doesn't mess up the url
url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'attributes' : attributes.replace('','+') 
            }

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'fWX7sIzv_WTgZXdSwxYBPg',
#    'alias': 'yong-kang-street-new-york-5',
#    'name': 'Yong Kang Street',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wKskm9a8gKMd7rcwnuDYNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yong-kang-street-new-york-5?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 77,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74822, 'longitude': -73.98874},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '888 6th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['888 6th Ave', 'New York, NY 10001']},
#    'phone': '+12129517357',
#    'display_phone': '(212) 951-7357',
#    'distance': 1592.2125407933247},
#   {'id': 'BtsXojrMtfLRhhFK7rm35A',
#    'alias': 'hupo琥珀-long-island-city-8',
#    'name': 'Hupo琥珀',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xi6O5g_plILSwUtBs1Vkdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hupo%E7%90%A5%E7%8F%80-long-island-city-8?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 24,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742827, 'longitude': -73.953575},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '1007 50th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1007 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17182556722',
#    'display_phone': '(718) 255-6722',
#    'distance': 2851.747990846802},
#   {'id': 'xq0cX_DgxiJMXwhmEl9kUA',
#    'alias': 'café-china-new-york-2',
#    'name': 'Café China',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UhHqxEX2epOvrBFI2pgRzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-china-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1581,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7499225208569,
#     'longitude': -73.9819464127197},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '13 E 37th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 E 37th St', 'New York, NY 10016']},
#    'phone': '+12122132810',
#    'display_phone': '(212) 213-2810',
#    'distance': 1180.6956479004084},
#   {'id': 'ojbH3wnRu050hRhkmoxRiA',
#    'alias': 'han-dynasty-new-york-4',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fe5QaNZH6Qc-dbIDPwE2Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-new-york-4?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 577,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78752, 'longitude': -73.97647},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '215 W 85th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 W 85th St', 'New York, NY 10024']},
#    'phone': '+12128589060',
#    'display_phone': '(212) 858-9060',
#    'distance': 3045.824094143192},
#   {'id': 'FXhSEZfIqjMZh4hR0_8jMQ',
#    'alias': 'china-xiang-中国湘-new-york-2',
#    'name': 'China Xiang 中国湘',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MC6-poc5wb7mP-jO7qfHHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-xiang-%E4%B8%AD%E5%9B%BD%E6%B9%98-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 442,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7582902125633,
#     'longitude': -73.9925113993899},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '360 W 42nd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['360 W 42nd Street', 'New York, NY 10036']},
#    'phone': '+12129676088',
#    'display_phone': '(212) 967-6088',
#    'distance': 1199.3368442478525},
#   {'id': '6tASYtO9zOrXr8-LPnAToQ',
#    'alias': 'zest-szechuan-new-york',
#    'name': 'Zest Szechuan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gRwi2bF4FXIZKHgFObryqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zest-szechuan-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 559,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75274, 'longitude': -73.98445},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45 W 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 W 39th St', 'New York, NY 10018']},
#    'phone': '+16468700521',
#    'display_phone': '(646) 870-0521',
#    'distance': 971.2384767814051},
#   {'id': 'oowNI_aUmGEFa_VW8BFgRg',
#    'alias': 'tri-dim-shanghai-new-york-2',
#    'name': 'Tri Dim Shanghai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-HycyO1XNiKGN8q28RYATg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tri-dim-shanghai-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 357,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77395, 'longitude': -73.95793},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1378 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1378 3rd Ave', 'New York, NY 10075']},
#    'phone': '+12125853388',
#    'display_phone': '(212) 585-3388',
#    'distance': 2311.776214972571},
#   {'id': 'sfsjk1h50ooC2ioY7m48gw',
#    'alias': 'pig-heaven-new-york-3',
#    'name': 'Pig Heaven',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YzHJPPxM5m6qp_vwfrC6SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pig-heaven-new-york-3?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 363,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77544, 'longitude': -73.95686},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1420 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1420 3rd Ave', 'New York, NY 10028']},
#    'phone': '+12127444333',
#    'display_phone': '(212) 744-4333',
#    'distance': 2489.5030051234776},
#   {'id': '0dDCDQz7DrKkSvu9h2hcQw',
#    'alias': 'chow-house-new-york',
#    'name': 'Chow House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RjYtwkmpojua4JmC_jXu0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chow-house-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 346,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72915, 'longitude': -74.00072},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '181 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12128371021',
#    'display_phone': '(212) 837-1021',
#    'distance': 3928.8169129232433},
#   {'id': 'bVkjBJlAIwKAj9Aw1KVWjA',
#    'alias': 'dim-sum-palace-new-york-8',
#    'name': 'Dim Sum Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CaAY18TnjUce10XYC3zcgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-palace-new-york-8?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1176,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76015, 'longitude': -73.9893699},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '334 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['334 W 46th St', 'New York, NY 10036']},
#    'phone': '+16468611910',
#    'display_phone': '(646) 861-1910',
#    'distance': 913.3425917326555},
#   {'id': 'QaolMEijS7L6eodSneOdng',
#    'alias': 'tri-dim-west-new-york-4',
#    'name': 'Tri Dim West',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N-YlevGHM_fG7NI_5xRbzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tri-dim-west-new-york-4?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 62,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78412, 'longitude': -73.97368},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '467 Columbus Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['467 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+12125851398',
#    'display_phone': '(212) 585-1398',
#    'distance': 2688.936836316399},
#   {'id': 'LT0yyLNM84EiJj9DL0rfHA',
#    'alias': 'hui-restaurant-and-bar-new-york',
#    'name': 'Hui Restaurant & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u-LVF-RzH6tHY_ghZdVB2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hui-restaurant-and-bar-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 127,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76701, 'longitude': -73.95846},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '314 E 70th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['314 E 70th St', 'New York, NY 10021']},
#    'phone': '+16468690339',
#    'display_phone': '(646) 869-0339',
#    'distance': 1840.1312272535458},
#   {'id': 'wfhMIiMh2A2psCGONOVSlg',
#    'alias': 'han-dynasty-new-york',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yQ7sAC3VpCD8KgT1DC7jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1211,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732072, 'longitude': -73.988074},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '90 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12123908685',
#    'display_phone': '(212) 390-8685',
#    'distance': 3231.601932577536},
#   {'id': 'TzhAlljC_843JO7UDDUIaQ',
#    'alias': 'the-tang-upper-west-side-new-york',
#    'name': 'The Tang - Upper West Side',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uNjNuc-pjoRbYNpompLGWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tang-upper-west-side-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 170,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80005, 'longitude': -73.966393},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '920 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['920 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+16465967970',
#    'display_phone': '(646) 596-7970',
#    'distance': 4538.220225016991},
#   {'id': 'qrncvjkiKN5Z-JC06ygy6A',
#    'alias': 'hutong-new-york',
#    'name': 'Hutong',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jyrAnQ9Lt8OdQgL2uYqO-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hutong-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 210,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761551, 'longitude': -73.967443},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '731 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['731 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12127584800',
#    'display_phone': '(212) 758-4800',
#    'distance': 943.0658249784433},
#   {'id': 'xCHApgtkLpEyh0lz-uhZvg',
#    'alias': 'szechuan-garden-new-york',
#    'name': 'Szechuan Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3d8C9K9bp0iR0feJRUA9ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/szechuan-garden-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 289,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80053, 'longitude': -73.967586},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '239 W 105th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 W 105th St', 'New York, NY 10025']},
#    'phone': '+12128658808',
#    'display_phone': '(212) 865-8808',
#    'distance': 4578.444408136007},
#   {'id': 'HScFap2SwbUlfC-QXVkxFA',
#    'alias': 'xian-famous-foods-new-york-39',
#    'name': "Xi'an Famous Foods",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tYakGJwZLl-MjEU8SJI7rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-famous-foods-new-york-39?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1645,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75606, 'longitude': -73.9808},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '24 W 45th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 W 45th St', 'New York, NY 10036']},
#    'phone': '+12127862068',
#    'display_phone': '(212) 786-2068',
#    'distance': 500.9635036717953},
#   {'id': 'v0opDMezc6pKgdfR22KUnQ',
#    'alias': 'da-tang-szechuan-new-york-2',
#    'name': 'Da Tang Szechuan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ByzWS78I4dlPB3U1HXVLDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-tang-szechuan-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 192,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75128, 'longitude': -73.98376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '18 W 38th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 W 38th St', 'New York, NY 10018']},
#    'phone': '+16464788345',
#    'display_phone': '(646) 478-8345',
#    'distance': 1095.7937919448566},
#   {'id': 'X8ZS-dgiMIJvhwf9SaDnjw',
#    'alias': 'wah-fung-no-1-fast-food-new-york-3',
#    'name': 'Wah Fung No 1 Fast Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1358,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71735, 'longitude': -73.99457},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '79 Chrystie St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129255175',
#    'display_phone': '(212) 925-5175',
#    'distance': 4955.254078383452},
#   {'id': 'gJXNSJ9VXTuCFmp_Kl9TVQ',
#    'alias': 'shanghai-new-york',
#    'name': 'Shanghai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XYzEFwVvzdA68G-4ZkOnPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shanghai-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 92,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.768291, 'longitude': -73.958381},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1388 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1388 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12122888066',
#    'display_phone': '(212) 288-8066',
#    'distance': 1917.304559842208}],
#  'total': 3600,
#  'region': {'center': {'longitude': -73.97850036621094,
#    'latitude': 40.76021491079617}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'fWX7sIzv_WTgZXdSwxYBPg',
#    'alias': 'yong-kang-street-new-york-5',
#    'name': 'Yong Kang Street',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wKskm9a8gKMd7rcwnuDYNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yong-kang-street-new-york-5?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 77,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74822, 'longitude': -73.98874},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '888 6th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['888 6th Ave', 'New York, NY 10001']},
#    'phone': '+12129517357',
#    'display_phone': '(212) 951-7357',
#    'distance': 1592.2125407933247},
#   {'id': 'BtsXojrMtfLRhhFK7rm35A',
#    'alias': 'hupo琥珀-long-island-city-8',
#    'name': 'Hupo琥珀',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Xi6O5g_plILSwUtBs1Vkdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hupo%E7%90%A5%E7%8F%80-long-island-city-8?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 24,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742827, 'longitude': -73.953575},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '1007 50th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1007 50th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17182556722',
#    'display_phone': '(718) 255-6722',
#    'distance': 2851.747990846802},
#   {'id': 'xq0cX_DgxiJMXwhmEl9kUA',
#    'alias': 'café-china-new-york-2',
#    'name': 'Café China',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UhHqxEX2epOvrBFI2pgRzg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caf%C3%A9-china-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1581,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7499225208569,
#     'longitude': -73.9819464127197},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '13 E 37th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['13 E 37th St', 'New York, NY 10016']},
#    'phone': '+12122132810',
#    'display_phone': '(212) 213-2810',
#    'distance': 1180.6956479004084},
#   {'id': 'ojbH3wnRu050hRhkmoxRiA',
#    'alias': 'han-dynasty-new-york-4',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fe5QaNZH6Qc-dbIDPwE2Ww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-new-york-4?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 577,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78752, 'longitude': -73.97647},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '215 W 85th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['215 W 85th St', 'New York, NY 10024']},
#    'phone': '+12128589060',
#    'display_phone': '(212) 858-9060',
#    'distance': 3045.824094143192},
#   {'id': 'FXhSEZfIqjMZh4hR0_8jMQ',
#    'alias': 'china-xiang-中国湘-new-york-2',
#    'name': 'China Xiang 中国湘',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MC6-poc5wb7mP-jO7qfHHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-xiang-%E4%B8%AD%E5%9B%BD%E6%B9%98-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 442,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7582902125633,
#     'longitude': -73.9925113993899},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '360 W 42nd Street',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['360 W 42nd Street', 'New York, NY 10036']},
#    'phone': '+12129676088',
#    'display_phone': '(212) 967-6088',
#    'distance': 1199.3368442478525},
#   {'id': '6tASYtO9zOrXr8-LPnAToQ',
#    'alias': 'zest-szechuan-new-york',
#    'name': 'Zest Szechuan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gRwi2bF4FXIZKHgFObryqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zest-szechuan-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 559,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75274, 'longitude': -73.98445},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '45 W 39th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 W 39th St', 'New York, NY 10018']},
#    'phone': '+16468700521',
#    'display_phone': '(646) 870-0521',
#    'distance': 971.2384767814051},
#   {'id': 'oowNI_aUmGEFa_VW8BFgRg',
#    'alias': 'tri-dim-shanghai-new-york-2',
#    'name': 'Tri Dim Shanghai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-HycyO1XNiKGN8q28RYATg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tri-dim-shanghai-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 357,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77395, 'longitude': -73.95793},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1378 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1378 3rd Ave', 'New York, NY 10075']},
#    'phone': '+12125853388',
#    'display_phone': '(212) 585-3388',
#    'distance': 2311.776214972571},
#   {'id': 'sfsjk1h50ooC2ioY7m48gw',
#    'alias': 'pig-heaven-new-york-3',
#    'name': 'Pig Heaven',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YzHJPPxM5m6qp_vwfrC6SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pig-heaven-new-york-3?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 363,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77544, 'longitude': -73.95686},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1420 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1420 3rd Ave', 'New York, NY 10028']},
#    'phone': '+12127444333',
#    'display_phone': '(212) 744-4333',
#    'distance': 2489.5030051234776},
#   {'id': '0dDCDQz7DrKkSvu9h2hcQw',
#    'alias': 'chow-house-new-york',
#    'name': 'Chow House',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RjYtwkmpojua4JmC_jXu0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chow-house-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 346,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72915, 'longitude': -74.00072},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '181 Bleecker St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['181 Bleecker St', 'New York, NY 10012']},
#    'phone': '+12128371021',
#    'display_phone': '(212) 837-1021',
#    'distance': 3928.8169129232433},
#   {'id': 'bVkjBJlAIwKAj9Aw1KVWjA',
#    'alias': 'dim-sum-palace-new-york-8',
#    'name': 'Dim Sum Palace',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CaAY18TnjUce10XYC3zcgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dim-sum-palace-new-york-8?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1176,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.76015, 'longitude': -73.9893699},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '334 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['334 W 46th St', 'New York, NY 10036']},
#    'phone': '+16468611910',
#    'display_phone': '(646) 861-1910',
#    'distance': 913.3425917326555},
#   {'id': 'QaolMEijS7L6eodSneOdng',
#    'alias': 'tri-dim-west-new-york-4',
#    'name': 'Tri Dim West',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/N-YlevGHM_fG7NI_5xRbzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tri-dim-west-new-york-4?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 62,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78412, 'longitude': -73.97368},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '467 Columbus Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['467 Columbus Ave', 'New York, NY 10024']},
#    'phone': '+12125851398',
#    'display_phone': '(212) 585-1398',
#    'distance': 2688.936836316399},
#   {'id': 'LT0yyLNM84EiJj9DL0rfHA',
#    'alias': 'hui-restaurant-and-bar-new-york',
#    'name': 'Hui Restaurant & Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/u-LVF-RzH6tHY_ghZdVB2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hui-restaurant-and-bar-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 127,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76701, 'longitude': -73.95846},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '314 E 70th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['314 E 70th St', 'New York, NY 10021']},
#    'phone': '+16468690339',
#    'display_phone': '(646) 869-0339',
#    'distance': 1840.1312272535458},
#   {'id': 'wfhMIiMh2A2psCGONOVSlg',
#    'alias': 'han-dynasty-new-york',
#    'name': 'Han Dynasty',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0yQ7sAC3VpCD8KgT1DC7jw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-dynasty-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1211,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732072, 'longitude': -73.988074},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '90 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['90 3rd Ave', 'New York, NY 10003']},
#    'phone': '+12123908685',
#    'display_phone': '(212) 390-8685',
#    'distance': 3231.601932577536},
#   {'id': 'TzhAlljC_843JO7UDDUIaQ',
#    'alias': 'the-tang-upper-west-side-new-york',
#    'name': 'The Tang - Upper West Side',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uNjNuc-pjoRbYNpompLGWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-tang-upper-west-side-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 170,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.80005, 'longitude': -73.966393},
#    'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '920 Amsterdam Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['920 Amsterdam Ave', 'New York, NY 10025']},
#    'phone': '+16465967970',
#    'display_phone': '(646) 596-7970',
#    'distance': 4538.220225016991},
#   {'id': 'qrncvjkiKN5Z-JC06ygy6A',
#    'alias': 'hutong-new-york',
#    'name': 'Hutong',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jyrAnQ9Lt8OdQgL2uYqO-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hutong-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 210,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761551, 'longitude': -73.967443},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '731 Lexington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['731 Lexington Ave', 'New York, NY 10022']},
#    'phone': '+12127584800',
#    'display_phone': '(212) 758-4800',
#    'distance': 943.0658249784433},
#   {'id': 'xCHApgtkLpEyh0lz-uhZvg',
#    'alias': 'szechuan-garden-new-york',
#    'name': 'Szechuan Garden',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3d8C9K9bp0iR0feJRUA9ZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/szechuan-garden-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 289,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80053, 'longitude': -73.967586},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '239 W 105th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['239 W 105th St', 'New York, NY 10025']},
#    'phone': '+12128658808',
#    'display_phone': '(212) 865-8808',
#    'distance': 4578.444408136007},
#   {'id': 'HScFap2SwbUlfC-QXVkxFA',
#    'alias': 'xian-famous-foods-new-york-39',
#    'name': "Xi'an Famous Foods",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tYakGJwZLl-MjEU8SJI7rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/xian-famous-foods-new-york-39?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1645,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75606, 'longitude': -73.9808},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '24 W 45th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['24 W 45th St', 'New York, NY 10036']},
#    'phone': '+12127862068',
#    'display_phone': '(212) 786-2068',
#    'distance': 500.9635036717953},
#   {'id': 'v0opDMezc6pKgdfR22KUnQ',
#    'alias': 'da-tang-szechuan-new-york-2',
#    'name': 'Da Tang Szechuan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ByzWS78I4dlPB3U1HXVLDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/da-tang-szechuan-new-york-2?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 192,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.75128, 'longitude': -73.98376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '18 W 38th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['18 W 38th St', 'New York, NY 10018']},
#    'phone': '+16464788345',
#    'display_phone': '(646) 478-8345',
#    'distance': 1095.7937919448566},
#   {'id': 'X8ZS-dgiMIJvhwf9SaDnjw',
#    'alias': 'wah-fung-no-1-fast-food-new-york-3',
#    'name': 'Wah Fung No 1 Fast Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 1358,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71735, 'longitude': -73.99457},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '79 Chrystie St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79 Chrystie St', 'New York, NY 10002']},
#    'phone': '+12129255175',
#    'display_phone': '(212) 925-5175',
#    'distance': 4955.254078383452},
#   {'id': 'gJXNSJ9VXTuCFmp_Kl9TVQ',
#    'alias': 'shanghai-new-york',
#    'name': 'Shanghai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/XYzEFwVvzdA68G-4ZkOnPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shanghai-new-york?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#    'review_count': 92,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.768291, 'longitude': -73.958381},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1388 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1388 2nd Ave', 'New York, NY 10021']},
#    'phone': '+12122888066',
#    'display_phone': '(212) 288-8066',
#    'distance': 1917.304559842208}],
#  'total': 3600,
#  'region': {'center': {'longitude': -73.97850036621094,
#    'latitude': 40.76021491079617}}}

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
data = response.json()

# %%
for key in data.keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n') #Seperate out data
# Out:
# businesses
# <class 'list'>
#
#
#
# total
# <class 'int'>
#
#
#
# region
# <class 'dict'>

# %% [markdown]
# Let's make sure our data is as expected by looking at a couple of different business by taking a slice of the data.

# %%
data['businesses'][3]
# Out:
# {'id': 'ojbH3wnRu050hRhkmoxRiA',
#  'alias': 'han-dynasty-new-york-4',
#  'name': 'Han Dynasty',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fe5QaNZH6Qc-dbIDPwE2Ww/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/han-dynasty-new-york-4?adjust_creative=iEJoh9Ld1tFc56m-OVijoA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=iEJoh9Ld1tFc56m-OVijoA',
#  'review_count': 577,
#  'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.78752, 'longitude': -73.97647},
#  'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '215 W 85th St',
#   'address2': '',
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10024',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['215 W 85th St', 'New York, NY 10024']},
#  'phone': '+12128589060',
#  'display_phone': '(212) 858-9060',
#  'distance': 3045.824094143192}

# %% [markdown]
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a tuple with the name, display_address, and one other data point of your choice.

# %%
#businesses returned will be 20
business = data['businesses'][10]

# %%
biz_tuple = (business['name'], ' '.join(business['location']['display_address']), business['rating'])

# %%
biz_tuple
# Out:
# ('Tri Dim West', '467 Columbus Ave New York, NY 10024', 4.5)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
#when something breaks in a for loop, print the iterator to see which element of the loop it broke on
def parse_data(data):
    # create a container to hold our parsed data
    business_data = []
    
    # loop through our business and parse each individual business
    for i in data['businesses']:
        business_data.append((i['name'], ' '.join(i['location']['display_address']), i['rating']))
    
    return business_data
    
    
    # in the loop, add each individual parsed parsed business to our data container
    
    # return the container with all of the parsed results

# %%
parse_data(data)
# Out:
# [('Yong Kang Street', '888 6th Ave New York, NY 10001', 4.0),
#  ('Hupo琥珀', '1007 50th Ave Long Island City, NY 11101', 4.5),
#  ('Café China', '13 E 37th St New York, NY 10016', 4.0),
#  ('Han Dynasty', '215 W 85th St New York, NY 10024', 4.0),
#  ('China Xiang 中国湘', '360 W 42nd Street New York, NY 10036', 4.0),
#  ('Zest Szechuan', '45 W 39th St New York, NY 10018', 4.0),
#  ('Tri Dim Shanghai', '1378 3rd Ave New York, NY 10075', 4.0),
#  ('Pig Heaven', '1420 3rd Ave New York, NY 10028', 4.0),
#  ('Chow House', '181 Bleecker St New York, NY 10012', 4.5),
#  ('Dim Sum Palace', '334 W 46th St New York, NY 10036', 4.0),
#  ('Tri Dim West', '467 Columbus Ave New York, NY 10024', 4.5),
#  ('Hui Restaurant & Bar', '314 E 70th St New York, NY 10021', 4.5),
#  ('Han Dynasty', '90 3rd Ave New York, NY 10003', 4.0),
#  ('The Tang - Upper West Side', '920 Amsterdam Ave New York, NY 10025', 4.5),
#  ('Hutong', '731 Lexington Ave New York, NY 10022', 3.5),
#  ('Szechuan Garden', '239 W 105th St New York, NY 10025', 4.0),
#  ("Xi'an Famous Foods", '24 W 45th St New York, NY 10036', 4.0),
#  ('Da Tang Szechuan', '18 W 38th St New York, NY 10018', 4.5),
#  ('Wah Fung No 1 Fast Food', '79 Chrystie St New York, NY 10002', 4.5),
#  ('Shanghai', '1388 2nd Ave New York, NY 10021', 4.0)]
